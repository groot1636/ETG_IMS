# %%
import json

# %%
fd = open("invent.json",'r')
r = fd.read()
fd.close()

db = json.loads(r)

# %%
db
# Out:
# {'2101': {'Name': 'Fanta',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 118,
#   'wt': '1.25l'},
#  '2102': {'Name': 'Cocacola',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 110,
#   'wt': '1.25l'},
#  '2103': {'Name': 'Sprite',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 80,
#   'wt': '1.25l'},
#  '2104': {'Name': 'Lahori Jeera',
#   'Category': 'Drinks',
#   'Unit_Price': 15,
#   'Quantity': 180,
#   'wt': '0.25l'},
#  '2105': {'Name': 'Fox Nuts',
#   'Category': 'Seeds',
#   'Unit_Price': 70,
#   'Quantity': 90,
#   'wt': '250gm'},
#  '2106': {'Name': 'Pumpkin Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 125,
#   'Quantity': 79,
#   'wt': '250gm'},
#  '2107': {'Name': 'Flax Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 195,
#   'Quantity': 96,
#   'wt': '250gm'},
#  '2108': {'Name': 'Chia Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 275,
#   'Quantity': 118,
#   'wt': '250gm'},
# ...

# %%
prod_id = str(input("Enter product id:"))
if prod_id in db.keys():
    Quantity = int(input("Enter quantity:"))
    db[prod_id]['Quantity'] += Quantity

else:
    Name = input("Enter name:")
    Unit_Price = int(input("Enter price:"))
    Quantity = int(input("Enter quantity:"))
    wt = input("Enter Weight")
    db[prod_id] = {'Name': name, 'Unit_Price': Unit_Price, 'Quantity': Quantity, 'wt' :wt }

js = json.dumps(db)

fd = open("invent.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:2101
# Enter quantity:34

# %%
db
# Out:
# {'2101': {'Name': 'Fanta',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 152,
#   'wt': '1.25l'},
#  '2102': {'Name': 'Cocacola',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 110,
#   'wt': '1.25l'},
#  '2103': {'Name': 'Sprite',
#   'Category': 'Drinks',
#   'Unit_Price': 45,
#   'Quantity': 80,
#   'wt': '1.25l'},
#  '2104': {'Name': 'Lahori Jeera',
#   'Category': 'Drinks',
#   'Unit_Price': 15,
#   'Quantity': 180,
#   'wt': '0.25l'},
#  '2105': {'Name': 'Fox Nuts',
#   'Category': 'Seeds',
#   'Unit_Price': 70,
#   'Quantity': 90,
#   'wt': '250gm'},
#  '2106': {'Name': 'Pumpkin Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 125,
#   'Quantity': 79,
#   'wt': '250gm'},
#  '2107': {'Name': 'Flax Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 195,
#   'Quantity': 96,
#   'wt': '250gm'},
#  '2108': {'Name': 'Chia Seeds',
#   'Category': 'Seeds',
#   'Unit_Price': 275,
#   'Quantity': 118,
#   'wt': '250gm'},
# ...
